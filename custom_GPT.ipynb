# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush104/Custom_GPT/blob/main/custom_GPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# raw text dataset to train
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
